# %% [markdown]
# ## Creating DataFrame by reading from csv file

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/luffy/Documents/Data_Science/Pandas/raw_data/stack_overflow_2024_data/survey_results_public.csv")

# %%
schema_df = pd.read_csv("/home/luffy/Documents/Data_Science/Pandas/raw_data/stack_overflow_2024_data/survey_results_schema.csv")

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age           Employment                            RemoteWork   Check  \
# 0               1  I am a developer by profession  Under 18 years old  Employed, full-time                                Remote  Apples
# 1               2  I am a developer by profession     35-44 years old  Employed, full-time                                Remote  Apples
# 2               3  I am a developer by profession     45-54 years old  Employed, full-time                                Remote  Apples
# 3               4           I am learning to code     18-24 years old   Student, full-time                                   NaN  Apples
# 4               5  I am a developer by profession     18-24 years old   Student, full-time                                   NaN  Apples
# ...           ...                             ...                 ...                  ...                                   ...     ...
# ...

# %% [markdown]
# ## Creating DataFrame Via Dictionary

# %%
people ={
    "first":["Corey","Jane","John"],
    "last":["Scheafer","Doe","Doe"],
    "email":["Corey@gmail.com","JaneDoe@gmail.com","JohnDoe@gmail.com"]
}

# %%
people['email']
# Out:
# ['Corey@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']

# %%
import pandas as pd

# %%
people_df = pd.DataFrame(people)
people_df
# Out:
#    first      last              email
# 0  Corey  Scheafer    Corey@gmail.com
# 1   Jane       Doe  JaneDoe@gmail.com
# 2   John       Doe  JohnDoe@gmail.com

# %%
people_df['email']
# Out:
# 0      Corey@gmail.com
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
type(people_df['email'])
# Out:
# pandas.core.series.Series

# %%
people_df.email
# Out:
# 0      Corey@gmail.com
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
people_df[["last","email"]]
# Out:
#        last              email
# 0  Scheafer    Corey@gmail.com
# 1       Doe  JaneDoe@gmail.com
# 2       Doe  JohnDoe@gmail.com

# %%
type(people_df[["last","email"]])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
people_df.iloc[0]
# Out:
# first              Corey
# last            Scheafer
# email    Corey@gmail.com
# Name: 0, dtype: object

# %%
people_df.iloc[[0,1],2]
# Out:
# 0      Corey@gmail.com
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %%
people_df.iloc[[0,1],[0,2]]
# Out:
#    first              email
# 0  Corey    Corey@gmail.com
# 1   Jane  JaneDoe@gmail.com

# %%
 people_df.loc[1,'email']
# Out:
# 'JaneDoe@gmail.com'

# %%
 people_df.loc[[1,2],['email','last']]
# Out:
#                email last
# 1  JaneDoe@gmail.com  Doe
# 2  JohnDoe@gmail.com  Doe

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
schema_df.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
df['LearnCode']
# Out:
# 0                                   Books / Physical media
# 1        Books / Physical media;Colleague;On the job tr...
# 2        Books / Physical media;Colleague;On the job tr...
# 3        Other online resources (e.g., videos, blogs, f...
# 4        Other online resources (e.g., videos, blogs, f...
#                                ...
# 65432    On the job training;School (i.e., University, ...
# 65433                                                  NaN
# 65434    Other online resources (e.g., videos, blogs, f...
# 65435    On the job training;Other online resources (e....
# 65436                                                  NaN
# Name: LearnCode, Length: 65437, dtype: object

# %%
df.loc[4]
# Out:
# ResponseId                                                                        5
# MainBranch                                           I am a developer by profession
# Age                                                                 18-24 years old
# Employment                                                       Student, full-time
# RemoteWork                                                                      NaN
# Check                                                                        Apples
# CodingActivities                                                                NaN
# EdLevel                           Secondary school (e.g. American high school, G...
# LearnCode                         Other online resources (e.g., videos, blogs, f...
# LearnCodeOnline                   Technical documentation;Blogs;Written Tutorial...
# TechDoc                           API document(s) and/or SDK document(s);User gu...
# ...

# %%
df.loc[4,'LearnCode']
# Out:
# 'Other online resources (e.g., videos, blogs, forum, online community)'

# %%
df.loc[[0,1,2,3,4],'LearnCode']
# Out:
# 0                               Books / Physical media
# 1    Books / Physical media;Colleague;On the job tr...
# 2    Books / Physical media;Colleague;On the job tr...
# 3    Other online resources (e.g., videos, blogs, f...
# 4    Other online resources (e.g., videos, blogs, f...
# Name: LearnCode, dtype: object

# %%
df.loc[0:4,'LearnCode']
# Out:
# 0                               Books / Physical media
# 1    Books / Physical media;Colleague;On the job tr...
# 2    Books / Physical media;Colleague;On the job tr...
# 3    Other online resources (e.g., videos, blogs, f...
# 4    Other online resources (e.g., videos, blogs, f...
# Name: LearnCode, dtype: object

# %%
df.loc[0:4,'MainBranch':'LearnCode']
# Out:
#                        MainBranch                 Age           Employment RemoteWork   Check                                   CodingActivities  \
# 0  I am a developer by profession  Under 18 years old  Employed, full-time     Remote  Apples                                              Hobby
# 1  I am a developer by profession     35-44 years old  Employed, full-time     Remote  Apples  Hobby;Contribute to open-source projects;Other...
# 2  I am a developer by profession     45-54 years old  Employed, full-time     Remote  Apples  Hobby;Contribute to open-source projects;Other...
# 3           I am learning to code     18-24 years old   Student, full-time        NaN  Apples                                                NaN
# 4  I am a developer by profession     18-24 years old   Student, full-time        NaN  Apples                                                NaN
#
#                                              EdLevel                                          LearnCode
# ...
