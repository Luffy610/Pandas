# %%
import pandas as pd

# %%
df = pd.read_csv("/home/luffy/Documents/Data_Science/Pandas/raw_data/stack_overflow_2024_data/survey_results_public.csv", index_col='ResponseId')
schema_df = pd.read_csv("/home/luffy/Documents/Data_Science/Pandas/raw_data/stack_overflow_2024_data/survey_results_schema.csv",index_col='qname')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]

# %%
india_df.to_csv('../raw_data/stack_overflow_2024_data/filter_india.csv')

# %%
india_df.to_csv('../raw_data/stack_overflow_2024_data/filter_india.tsv', sep='\t')

# %%
india_df.to_excel('../raw_data/stack_overflow_2024_data/filter_india.xlsx')

# %%
test_df = pd.read_excel('/home/luffy/Documents/Data_Science/Pandas/raw_data/stack_overflow_2024_data/filter_india.xlsx', index_col='ResponseId')

# %%
test_df
# Out:
#                                                    MainBranch              Age                                         Employment RemoteWork   Check                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline                                            TechDoc YearsCode YearsCodePro                DevType                   OrgSize  \
# ResponseId
# 18                             I am a developer by profession  18-24 years old  Independent contractor, freelancer, or self-em...     Remote  Apples  Hobby;Professional development or self-paced l...       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Other online resources (e.g., videos, blogs, f...  Blogs;Coding sessions (live or recorded);How-t...                                                NaN         6            3   Developer, front-end                       NaN
# ...

# %%
india_df.to_json('../raw_data/stack_overflow_2024_data/filter_india.json')

# %%
india_df.to_json('../raw_data/stack_overflow_2024_data/filter_india.json', orient='records', lines=True)

# %%
test_df = pd.read_json('/home/luffy/Documents/Data_Science/Pandas/raw_data/stack_overflow_2024_data/filter_india.json', orient='records', lines=True)

# %%
test_df.head()
# Out:
#                                           MainBranch              Age                                         Employment RemoteWork   Check                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline TechDoc YearsCode YearsCodePro                DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse Country Currency  CompTotal  \
# 0                     I am a developer by profession  18-24 years old  Independent contractor, freelancer, or self-em...     Remote  Apples  Hobby;Professional development or self-paced l...       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Other online resources (e.g., videos, blogs, f...  Blogs;Coding sessions (live or recorded);How-t...    None         6            3   Developer, front-end    None              None       None       None        None   India     None        NaN
# ...
